# %% [markdown]
# # Jornada de Minicursos: Estatísticas
#
# ## Incrições por minicurso
#
# |  Minicurso  |  Inscritos  |  %  |
# | :------: | :------: | :------: |
# |*AED c/ R*|25|9.73|
# |*AED c/ Python*|35|13.62|
# |*Power BI*|48|18.68|
# |*R/RStudio*|18|7.00|
# |*LaTeX*|16|6.23|
# |*Git/Github*|29|11.28|
# |*Investimentos*|29|11.28|
# |*Oratória*|29|11.28|
# |*Primeiros* Socorros|28|10.89|
# |**Total**|257|100|
#
# <br>
#
# No total, os minicursos do PET tiveram aproximadamente **55.25% de inscrições**, enquanto os dos convidados, aproximadamente **44.75%** de inscrições.
#
# <br>
#
# ## Certificados emitidos por minicurso
#
# |  Minicurso  |  Certificados  |  % (em relação à cada um)  |
# | :------: | :------: | :------: |
# |*AED c/ R*|10|40.00|
# |*AED c/ Python*|15|42.86|
# |*Power BI*|32|66.67|
# |*R/RStudio*|7|38.89|
# |*LaTeX*|7|43.75|
# |*Git/Github*|22|75.86|
# |*Investimentos*|27|93.10|
# |*Oratória*|17|58.62|
# |*Primeiros Socorros*|20|71.43|
# |**Total**|157|---|
#
# <br>
#
# **OBS**: Recebem certificado apenas aqueles que compareceram **pelo menos 2 dias**, e que entregaram os kg's de alimentos correspondentes à quantidade de minicursos escolhidos.
#
# Ao todo, tivemos aproximadamente **61.09%** de certificados emitidos (relativos ao total de inscritos).
#
# Certificados para minicursos do PET Estatística compõem: **45.22%**, do total de certificados.
#
# Certificados para minicursos dos convidados compõem: **54.78%**, do total de certificados.
#
#
# <br>
#
# ## Quantidade de feedbacks por minicurso
#
# |  Minicurso  |  Qt.  |  %  (em relação às participações em cada um)|
# | :------: | :------: | :------: |
# |*AED c/ R*|7|70.00|
# |*AED c/ Python*|12|80.00|
# |*Power BI*|20|62.50|
# |*R/RStudio*|6|85.71|
# |*LaTeX*|0|0|
# |*Git/Github*|13|59.10|
# |*Investimentos*|13|48.10|
# |*Oratória*|7|41.10|
# |*Primeiros Socorros*|13|65.00|
# |**Total**|91|---|
#
# <br>
#
# **OBS**: o formulário de feedback do minicurso de *LaTeX* não foi enviado.
#
# Dos que participaram efetivamente, ao todo, obtivemos aproximadamente **57.96%** de respostas de feedback.
#
# Feedbacks para o PET: **49.45%**
#
# Feedbacks para os convidados: **50.55%**
#
# <br>
#
# ## Alimentos arrecadados
#
# |  Tipo  |  Qt.  |
# | :------:|:------:|
# |Arroz|94|
# |Feijão|10|
# |Macarrão|15|
# |Cuscuz|3|
# |Açucar|25|
# |Farinha|5|
# |**Total**|152|
